# %%
import os 
os.chdir("../..")
import numpy
import numpy as np
import pandas as pd
import datetime
from scripts.python.PdfParse import *
from scripts.python.ts_utils import *
from scripts.python.utils import *

# %%
samoa_folder = os.getcwd() + "/data/tourism/samoa/"
filepath = os.getcwd() + "/data/tourism/samoa/" + os.listdir(samoa_folder)[-1]

# %% [markdown]
# ## Samoa Census

# %%
samoa_raw = pd.read_excel(filepath)
samoa_raw.head(5)
# Out:
#   Table 1.                                                  TOURISM EARNINGS, AVERAGE EXPENDITURE AND TOURISM PRICE INDEX                                         \
# 0                                                NaN
# 1                                                NaN
# 2                           Total arrivals (persons)
# 3                      Arrivals, by market (persons)
# 4                                     American Samoa
#
#             Unnamed: 1           Unnamed: 2           Unnamed: 3  \
# 0                  NaN                  NaN                  NaN
# 1  2002-08-08 00:00:00  2002-09-08 00:00:00  2002-10-08 00:00:00
# 2                 8260                 6708                 5737
# 3                  NaN                  NaN                  NaN
# 4                 2877                 2119                 1892
#
#             Unnamed: 4           Unnamed: 5           Unnamed: 6  \
# 0                  NaN                  NaN                  NaN
# 1  2002-11-08 00:00:00  2002-12-08 00:00:00  2003-01-08 00:00:00
# 2                 6653                13042                 7555
# 3                  NaN                  NaN                  NaN
# 4                 2530                 4678                 2531
#
#             Unnamed: 7           Unnamed: 8           Unnamed: 9  ...  \
# 0                  NaN                  NaN                  NaN  ...
# 1  2003-02-08 00:00:00  2003-03-08 00:00:00  2003-04-08 00:00:00  ...
# 2                 5968                 5550                 7283  ...
# 3                  NaN                  NaN                  NaN  ...
# 4                 1993                 1858                 2319  ...
#
#           Unnamed: 235         Unnamed: 236         Unnamed: 237  \
# 0                  NaN                  NaN                  NaN
# 1  2022-02-08 00:00:00  2022-03-08 00:00:00  2022-04-08 00:00:00
# 2                    0                    0                    0
# 3                  NaN                  NaN                  NaN
# 4                    0                    0                    0
#
#           Unnamed: 238         Unnamed: 239         Unnamed: 240  \
# 0                  NaN                  NaN                  NaN
# 1  2022-05-08 00:00:00  2022-06-08 00:00:00  2022-07-08 00:00:00
# 2                    0                    0                    0
# 3                  NaN                  NaN                  NaN
# 4                    0                    0                    0
#
#           Unnamed: 241         Unnamed: 242 Unnamed: 243 Unnamed: 244
# 0                  NaN                  NaN          NaN          NaN
# 1  2022-08-08 00:00:00  2022-09-08 00:00:00          NaN          NaN
# 2                 6228                 8130          NaN          NaN
# 3                  NaN                  NaN          NaN          NaN
# 4                  692                  697          NaN          NaN
#
# [5 rows x 245 columns]

# %%
samon_byco = samoa_raw.iloc[:11, ]

# change the column name
colname = samon_byco.iloc[1].to_list()
colname[0] = "Country"
samon_byco.columns = colname

# drop irrelevant rows
samon_byco = (samon_byco.drop(index=[0, 1, 3])
              .reset_index()
              .drop("index", axis=1))

# reshape the data and change the colname again
samon_byco = samon_byco.T.reset_index()
colname_t = samon_byco.iloc[0].to_list()
colname_t[0] = "Date"
samon_byco.columns = colname_t

# reset the index
samon_byco = (samon_byco.drop(index=0)
              .dropna()
              .reset_index()
              .drop("index", axis=1))

# %%
# change the column format
samon_byco["Date"] = pd.to_datetime(samon_byco["Date"])
samon_byco["Year"], samon_byco["Month"] = samon_byco["Date"].dt.year, \
            samon_byco["Date"].dt.month


for col in samon_byco.columns:
    if col != "Date":
        samon_byco[col] = samon_byco[col].astype(float)

samon_byco.to_csv(samoa_folder + "samoa_byCon.csv", encoding="utf-8")
samon_byco.head(5)
# Out:
#         Date  Total arrivals (persons)     American Samoa     Australia  \
# 0 2002-08-08                    8260.0             2877.0        1115.0
# 1 2002-09-08                    6708.0             2119.0         972.0
# 2 2002-10-08                    5737.0             1892.0         737.0
# 3 2002-11-08                    6653.0             2530.0         864.0
# 4 2002-12-08                   13042.0             4678.0        1918.0
#
#       Europe     New Zealand     USA     Other Countries     Cruise ships  \
# 0      429.0          2035.0   933.0               871.0              0.0
# 1      372.0          1879.0   612.0               754.0              0.0
# 2      468.0          1492.0   577.0               571.0              0.0
# 3      393.0          1675.0   483.0               708.0              0.0
# 4      272.0          4401.0  1007.0               766.0              0.0
#
#      Year  Month
# 0  2002.0    8.0
# 1  2002.0    9.0
# 2  2002.0   10.0
# 3  2002.0   11.0
# 4  2002.0   12.0

# %%
get_adf_df(samon_byco.iloc[5:], ["Total arrivals (persons)"])
# Out:
#                           Test Statistic   p-value  # Lags Used  \
# Total arrivals (persons)       -3.408495  0.010673         14.0
#
#                           Number of Observations Used  Critical Value (1%)  \
# Total arrivals (persons)                        222.0            -3.460154
#
#                           Critical Value (5%)  Critical Value (10%)
# Total arrivals (persons)            -2.874649             -2.573757

# %%
# Perform the basic quality check
error_lst = check_quality(samon_byco, ["Date", "Cruise ships", "Year", "Month"], "Total arrivals (persons)")
samon_byco.iloc[error_lst]
# Out:
#           Date  Total arrivals (persons)     American Samoa     Australia  \
# 41  2006-01-08                    8025.0             1742.0        1517.0
# 50  2006-10-08                    8515.0             1765.0        1827.0
# 54  2007-02-08                    7201.0             1737.0        1179.0
# 57  2007-05-08                    9166.0             1878.0        1591.0
# 65  2008-01-08                    8940.0             1324.0        1870.0
# 66  2008-02-08                    6932.0             1317.0        1270.0
# 67  2008-03-08                    8165.0             1943.0        1283.0
# 68  2008-04-08                    8792.0             1815.0        1476.0
# 70  2008-06-08                   10733.0             2762.0        1712.0
# 71  2008-07-08                   12935.0             2553.0        1956.0
# 74  2008-10-08                    9716.0             1687.0        1663.0
# 113 2012-01-08                    9613.0             1541.0        2248.0
# 114 2012-02-08                    7245.0             1419.0        1295.0
# 122 2012-10-08                    9684.0             1175.0        1929.0
# 123 2012-11-08                    9456.0             1361.0        2010.0
# 124 2012-12-08                   16127.0             2983.0        4466.0
# 126 2013-02-08                    6547.0             1104.0        1334.0
# 127 2013-03-08                    8239.0             1570.0        1902.0
# 128 2013-04-08                    9511.0             1516.0        2151.0
# 129 2013-05-08                    9273.0             1603.0        1904.0
# 133 2013-09-08                   11227.0             1101.0        3021.0
# 134 2013-10-08                   10035.0             1369.0        2027.0
# 135 2013-11-08                    8957.0             1475.0        2171.0
# 138 2014-02-08                    7207.0             1201.0        1552.0
# 139 2014-03-08                    8120.0             1562.0        1767.0
# 140 2014-04-08                    9692.0             1417.0        2302.0
# 141 2014-05-08                   10497.0             1473.0        2369.0
# 145 2014-09-08                   11530.0             1111.0        3037.0
# 146 2014-10-08                   10348.0             1251.0        2393.0
# 147 2014-11-08                    9991.0             1003.0        2393.0
# 150 2015-02-08                    7440.0             1334.0        1547.0
# 151 2015-03-08                    8645.0             1317.0        2020.0
# 162 2016-02-08                    8226.0              653.0        1673.0
#    Available_seat_kilometers  Number_of_flights_domestic  \
# 0               1.430416e+07                           8
# 1               1.495610e+07                           8
# 2               1.592143e+07                          10
# 3               1.457334e+07                           7
# 4               1.773449e+07                           7
#
#    Number_of_flights_interregional  Number_of_flights_intraregional  \
# 0                                1                               10
# 1                                1                               10
# 2                                2                               12
# 3                                2                               12
# 4                                1                               12
#
#    Number_of_flights_intl  Number_of_flights_total
# 0                      11                       19
# 1                      11                       19
# 2                      14                       24
# 3                      14                       21
# 4                      13                       20

# %%
ws_avi = (aviation[(aviation.ISO == "WS") & (aviation.Aircraft_type == "passenger")]
          .reset_index()
          .drop("index", axis=1)
          [["Date", "Number_of_flights_intl", "Number_of_flights_total",
            "Seats_arrivals_intl", "Seats_arrivals_total"]])

dates = pd.DataFrame(pd.date_range(start="2019-01-01",
                                   end="2022-09-01"), columns=["Date"])

ws_avi = dates.merge(ws_avi, how="left", on="Date")
ws_avi["Date"] = pd.to_datetime(ws_avi["Date"])
ws_avi["Month"], ws_avi["Year"] = ws_avi["Date"].dt.month, ws_avi["Date"].dt.year

ws_avi_19_22 = ws_avi.groupby(by=["Year", "Month"]).sum().reset_index()

# %%
ws_avi_merged = ws_avi_19_22.merge(samon_byco, on=["Year", "Month"], how="left").drop("Date", axis=1)
ws_avi_merged.head(5)
# Out:
#    Year  Month  Number_of_flights_intl  Number_of_flights_total  \
# 0  2019      1                    90.0                     93.0
# 1  2019      2                    71.0                     84.0
# 2  2019      3                    85.0                    109.0
# 3  2019      4                    84.0                    117.0
# 4  2019      5                    85.0                    115.0
#
#    Seats_arrivals_intl  Seats_arrivals_total  Total arrivals (persons)  \
# 0              26332.0               26389.0                   13755.0
# 1              17320.0               17681.0                    9044.0
# 2              20843.0               21546.0                   11163.0
# 3              20801.0               21751.0                   14413.0
# 4              20843.0               21679.0                   13565.0
#
#       American Samoa     Australia     Europe     New Zealand     USA  \
# 0             1116.0        3434.0      612.0          6290.0   862.0
# 1              968.0        1820.0      458.0          3645.0   594.0
# 2             1089.0        2481.0      716.0          4400.0   981.0
# 3             1204.0        3122.0      658.0          6887.0   827.0
# 4             1215.0        3143.0      492.0          5742.0   962.0
#
#       Other Countries     Cruise ships
# 0              1441.0            500.0
# 1              1559.0           2180.0
# 2              1496.0           6730.0
# 3              1715.0           2519.0
# 4              2011.0              0.0

# %%
ws_avi_merged[["Seats_arrivals_total", "Seats_arrivals_intl", "Total arrivals (persons)"]].describe()
# Out:
#        Seats_arrivals_total  Seats_arrivals_intl  Total arrivals (persons)
# count             45.000000            45.000000                 45.000000
# mean            8688.955556          8474.466667               4819.755556
# std             9997.619560          9775.677134               6967.989045
# min              227.000000           227.000000                  0.000000
# 25%             1559.000000          1483.000000                  0.000000
# 50%             2431.000000          2186.000000                  0.000000
# 75%            20334.000000         20049.000000              10456.000000
# max            30302.000000         29238.000000              24647.000000

# %% [markdown]
# ## EDA
# ### Ratio

# %%
cols = ["Seats_arrivals_total", "Seats_arrivals_intl", "Number_of_flights_intl", "Number_of_flights_total", "Total arrivals (persons)"]

ws_avi_merged["total_ratio"] = (ws_avi_merged["Total arrivals (persons)"] + 1) / \
    ws_avi_merged["Seats_arrivals_total"]

# %% [markdown]
# ### Correlation
# #### Pearson

# %%
from scipy.stats import pearsonr


corr_seats, _ = pearsonr(
    ws_avi_merged["Seats_arrivals_total"], ws_avi_merged["Total arrivals (persons)"])
corr_seats_intl, _ = pearsonr(
    ws_avi_merged["Seats_arrivals_intl"],  ws_avi_merged["Total arrivals (persons)"])
print(
    f"Pearson Correlation between FlightRadar's Seats Arrival and WS's census data is{corr_seats: .4f}." 
    f"\nPearson Correlation between FlightRadar's # of Seats Arrival Intl and WS's census data is{corr_seats_intl: .4f}.")


corr_matrix = ws_avi_merged[cols].corr()
corr_matrix
# Out:
# Pearson Correlation between FlightRadar's Seats Arrival and WS's census data is 0.9528.
# Pearson Correlation between FlightRadar's # of Seats Arrival Intl and WS's census data is 0.9503.
#                           Seats_arrivals_total  Seats_arrivals_intl  \
# Seats_arrivals_total                  1.000000             0.999837
# Seats_arrivals_intl                   0.999837             1.000000
# Number_of_flights_intl                0.987905             0.987597
# Number_of_flights_total               0.983594             0.981157
# Total arrivals (persons)              0.952782             0.950264
#
#                           Number_of_flights_intl  Number_of_flights_total  \
# Seats_arrivals_total                    0.987905                 0.983594
# Seats_arrivals_intl                     0.987597                 0.981157
# Number_of_flights_intl                  1.000000                 0.992128
# Number_of_flights_total                 0.992128                 1.000000
# Total arrivals (persons)                0.942759                 0.957409
#
#                           Total arrivals (persons)
# Seats_arrivals_total                      0.952782
# Seats_arrivals_intl                       0.950264
# Number_of_flights_intl                    0.942759
# Number_of_flights_total                   0.957409
# Total arrivals (persons)                  1.000000

# %% [markdown]
# #### Cross-correlation

# %%
incl_cols = ["Total arrivals (persons)", "Seats_arrivals_intl"]
ws_cc = cross_corr_df(ws_avi_merged, "Seats_arrivals_intl", "Total arrivals (persons)")
ws_cc.head(5)
# Out:
#    lag  cross_corr_coef
# 0    0         0.950264
# 1    1         0.887686
# 2    2         0.848828
# 3    3         0.786986
# 4    4         0.695619

# %% [markdown]
# ### ADF test

# %%
get_adf_df(ws_avi_merged, incl_cols)
# Out:
#                           Test Statistic   p-value  # Lags Used  \
# Total arrivals (persons)       -2.306947  0.169737         10.0
# Seats_arrivals_intl            -1.703234  0.429447          7.0
#
#                           Number of Observations Used  Critical Value (1%)  \
# Total arrivals (persons)                         34.0            -3.639224
# Seats_arrivals_intl                              37.0            -3.620918
#
#                           Critical Value (5%)  Critical Value (10%)
# Total arrivals (persons)            -2.951230             -2.614447
# Seats_arrivals_intl                 -2.943539             -2.610400

# %%
ws_diff = ws_avi_merged.diff().dropna()
ws_diff2 = ws_diff.diff().dropna()
get_adf_df(ws_diff2, incl_cols)
# Out:
#                           Test Statistic       p-value  # Lags Used  \
# Total arrivals (persons)       -5.955568  2.097277e-07          4.0
# Seats_arrivals_intl            -2.271449  1.813417e-01         10.0
#
#                           Number of Observations Used  Critical Value (1%)  \
# Total arrivals (persons)                         38.0            -3.615509
# Seats_arrivals_intl                              32.0            -3.653520
#
#                           Critical Value (5%)  Critical Value (10%)
# Total arrivals (persons)            -2.941262             -2.609200
# Seats_arrivals_intl                 -2.957219             -2.617588

# %% [markdown]
# ### Granger's Causality Test

# %%
grangers_causation_matrix(ws_diff,incl_cols, maxlag=10)
# Out:
#                             Total arrivals (persons)_x  Seats_arrivals_intl_x
# Total arrivals (persons)_y                         1.0                    0.0
# Seats_arrivals_intl_y                              0.0                    1.0
