# %%
import os 
os.chdir("../..")
import numpy
import numpy as np
import pandas as pd
import datetime
from scripts.PdfParse import *
from scripts.SupportFunc import *

# %%
samoa_folder = os.getcwd() + "/data/tourism/samoa/"
filepath = os.getcwd() + "/data/tourism/samoa/" + os.listdir(samoa_folder)[-1]

# %% [markdown]
# ## Samoa Census

# %%
samoa_raw = pd.read_excel(filepath)
samoa_raw.head(5)
# Out:
#   Table 1.                                                  TOURISM EARNINGS, AVERAGE EXPENDITURE AND TOURISM PRICE INDEX                                         \
# 0                                                NaN
# 1                                                NaN
# 2                           Total arrivals (persons)
# 3                      Arrivals, by market (persons)
# 4                                     American Samoa
#
#             Unnamed: 1           Unnamed: 2           Unnamed: 3  \
# 0                  NaN                  NaN                  NaN
# 1  2002-08-08 00:00:00  2002-09-08 00:00:00  2002-10-08 00:00:00
# 2                 8260                 6708                 5737
# 3                  NaN                  NaN                  NaN
# 4                 2877                 2119                 1892
#
#             Unnamed: 4           Unnamed: 5           Unnamed: 6  \
# 0                  NaN                  NaN                  NaN
# 1  2002-11-08 00:00:00  2002-12-08 00:00:00  2003-01-08 00:00:00
# 2                 6653                13042                 7555
# 3                  NaN                  NaN                  NaN
# 4                 2530                 4678                 2531
#
#             Unnamed: 7           Unnamed: 8           Unnamed: 9  ...  \
# 0                  NaN                  NaN                  NaN  ...
# 1  2003-02-08 00:00:00  2003-03-08 00:00:00  2003-04-08 00:00:00  ...
# 2                 5968                 5550                 7283  ...
# 3                  NaN                  NaN                  NaN  ...
# 4                 1993                 1858                 2319  ...
#
#           Unnamed: 235         Unnamed: 236         Unnamed: 237  \
# 0                  NaN                  NaN                  NaN
# 1  2022-02-08 00:00:00  2022-03-08 00:00:00  2022-04-08 00:00:00
# 2                    0                    0                    0
# 3                  NaN                  NaN                  NaN
# 4                    0                    0                    0
#
#           Unnamed: 238         Unnamed: 239         Unnamed: 240  \
# 0                  NaN                  NaN                  NaN
# 1  2022-05-08 00:00:00  2022-06-08 00:00:00  2022-07-08 00:00:00
# 2                    0                    0                    0
# 3                  NaN                  NaN                  NaN
# 4                    0                    0                    0
#
#           Unnamed: 241         Unnamed: 242 Unnamed: 243 Unnamed: 244
# 0                  NaN                  NaN          NaN          NaN
# 1  2022-08-08 00:00:00  2022-09-08 00:00:00          NaN          NaN
# 2                 6228                 8130          NaN          NaN
# 3                  NaN                  NaN          NaN          NaN
# 4                  692                  697          NaN          NaN
#
# [5 rows x 245 columns]

# %%
samon_byco = samoa_raw.iloc[:11, ]

# change the column name
colname = samon_byco.iloc[1].to_list()
colname[0] = "Country"
samon_byco.columns = colname

# drop irrelevant rows
samon_byco = (samon_byco.drop(index=[0, 1, 3])
              .reset_index()
              .drop("index", axis=1))

# reshape the data and change the colname again
samon_byco = samon_byco.T.reset_index()
colname_t = samon_byco.iloc[0].to_list()
colname_t[0] = "Date"
samon_byco.columns = colname_t

# reset the index
samon_byco = (samon_byco.drop(index=0)
              .dropna()
              .reset_index()
              .drop("index", axis=1))

# %%
# change the column format
samon_byco["Date"] = pd.to_datetime(samon_byco["Date"])
samon_byco["Year"], samon_byco["Month"] = samon_byco["Date"].dt.year, \
            samon_byco["Date"].dt.month


for col in samon_byco.columns:
    if col != "Date":
        samon_byco[col] = samon_byco[col].astype(float)

samon_byco.to_csv(samoa_folder + "samoa_byCon.csv", encoding="utf-8")
samon_byco.head(5)
# Out:
#         Date  Total arrivals (persons)     American Samoa     Australia  \
# 0 2002-08-08                    8260.0             2877.0        1115.0
# 1 2002-09-08                    6708.0             2119.0         972.0
# 2 2002-10-08                    5737.0             1892.0         737.0
# 3 2002-11-08                    6653.0             2530.0         864.0
# 4 2002-12-08                   13042.0             4678.0        1918.0
#
#       Europe     New Zealand     USA     Other Countries     Cruise ships  \
# 0      429.0          2035.0   933.0               871.0              0.0
# 1      372.0          1879.0   612.0               754.0              0.0
# 2      468.0          1492.0   577.0               571.0              0.0
# 3      393.0          1675.0   483.0               708.0              0.0
# 4      272.0          4401.0  1007.0               766.0              0.0
#
#      Year  Month
# 0  2002.0    8.0
# 1  2002.0    9.0
# 2  2002.0   10.0
# 3  2002.0   11.0
# 4  2002.0   12.0

# %%
# Perform the basic quality check
error_lst = check_quality(samon_byco, ["Date", "Cruise ships"], "Total arrivals (persons)")

# %% [markdown]
# ## Aviation data

# %%
aviation_path = os.getcwd() + "/data/tourism/aviation_seats_flights_pic.xlsx"
aviation = pd.read_excel(aviation_path)
aviation.head(5)
# Out:
#   Country ISO               Region       Date Aircraft_type  \
# 0    Fiji  FJ  East Asia & Pacific 2019-01-01     passenger
# 1    Fiji  FJ  East Asia & Pacific 2019-01-02     passenger
# 2    Fiji  FJ  East Asia & Pacific 2019-01-03     passenger
# 3    Fiji  FJ  East Asia & Pacific 2019-01-04     passenger
# 4    Fiji  FJ  East Asia & Pacific 2019-01-05     passenger
#
#    Seats_arrivals_domestic  Seats_arrivals_interregional  \
# 0                      839                           273
# 1                      974                           313
# 2                     1190                           443
# 3                      831                           586
# 4                      744                           273
#
#    Seats_arrivals_intraregional  Seats_arrivals_intl  Seats_arrivals_total  \
# 0                          3480                 3753                  4592
# 1                          3471                 3784                  4758
# 2                          3675                 4118                  5308
# 3                          3159                 3745                  4576
# 4                          4752                 5025                  5769
#
#    Available_seat_kilometers  Number_of_flights_domestic  \
# 0               1.430416e+07                           8
# 1               1.495610e+07                           8
# 2               1.592143e+07                          10
# 3               1.457334e+07                           7
# 4               1.773449e+07                           7
#
#    Number_of_flights_interregional  Number_of_flights_intraregional  \
# 0                                1                               10
# 1                                1                               10
# 2                                2                               12
# 3                                2                               12
# 4                                1                               12
#
#    Number_of_flights_intl  Number_of_flights_total
# 0                      11                       19
# 1                      11                       19
# 2                      14                       24
# 3                      14                       21
# 4                      13                       20

# %%
ws_avi = (aviation[(aviation.ISO == "WS") & (aviation.Aircraft_type == "passenger")]
          .reset_index()
          .drop("index", axis=1)
          [["Date", "Number_of_flights_intl", "Number_of_flights_total",
            "Seats_arrivals_intl", "Seats_arrivals_total"]])

dates = pd.DataFrame(pd.date_range(start="2019-01-01",
                                   end="2022-09-01"), columns=["Date"])

ws_avi = dates.merge(ws_avi, how="left", on="Date")
ws_avi["Date"] = pd.to_datetime(ws_avi["Date"])
ws_avi["Month"], ws_avi["Year"] = ws_avi["Date"].dt.month, ws_avi["Date"].dt.year

ws_avi_19_22 = ws_avi.groupby(by=["Year", "Month"]).sum().reset_index()

# %%
ws_avi_19_22
# Out:
#     Year  Month  Number_of_flights_intl  Number_of_flights_total  \
# 0   2019      1                    90.0                     93.0
# 1   2019      2                    71.0                     84.0
# 2   2019      3                    85.0                    109.0
# 3   2019      4                    84.0                    117.0
# 4   2019      5                    85.0                    115.0
# 5   2019      6                    88.0                    110.0
# 6   2019      7                   112.0                    154.0
# 7   2019      8                    87.0                    110.0
# 8   2019      9                    83.0                    108.0
# 9   2019     10                    84.0                    107.0
# 10  2019     11                    82.0                     96.0
# 11  2019     12                    94.0                    115.0
# 12  2020      1                    91.0                     99.0
# 13  2020      2                    66.0                     73.0
# 14  2020      3                    44.0                     48.0
# 15  2020      4                     2.0                      2.0
# 16  2020      5                     5.0                      6.0
# 17  2020      6                     5.0                      7.0
# 18  2020      7                     5.0                      8.0
# 19  2020      8                     7.0                      7.0
# 20  2020      9                     4.0                      5.0
# 21  2020     10                     6.0                      7.0
# 22  2020     11                     4.0                      5.0
# 23  2020     12                     7.0                      7.0
# 24  2021      1                     7.0                      7.0
# 25  2021      2                     6.0                      6.0
# 26  2021      3                     6.0                     10.0
# 27  2021      4                     9.0                     16.0
# 28  2021      5                     4.0                      8.0
# 29  2021      6                     8.0                     10.0
# 30  2021      7                     6.0                      7.0
# 31  2021      8                     6.0                      9.0
# 32  2021      9                     7.0                      8.0
# 33  2021     10                     8.0                     10.0
# 34  2021     11                     8.0                     10.0
# 35  2021     12                     9.0                     11.0
# 36  2022      1                     4.0                      7.0
# 37  2022      2                     5.0                      6.0
# 38  2022      3                     9.0                     11.0
# 39  2022      4                     5.0                      7.0
# 40  2022      5                     9.0                     14.0
# 41  2022      6                    17.0                     19.0
# 42  2022      7                    32.0                     36.0
# 43  2022      8                    62.0                     64.0
# 44  2022      9                     2.0                      2.0
#
#     Seats_arrivals_intl  Seats_arrivals_total
# 0               26332.0               26389.0
# 1               17320.0               17681.0
# 2               20843.0               21546.0
# 3               20801.0               21751.0
# 4               20843.0               21679.0
# 5               21228.0               21874.0
# 6               29238.0               30302.0
# 7               22889.0               23497.0
# 8               22432.0               23116.0
# 9               21797.0               22424.0
# 10              20049.0               20334.0
# 11              27241.0               27659.0
# 12              25747.0               25937.0
# 13              15636.0               15769.0
# 14               9785.0                9880.0
# 15                378.0                 378.0
# 16                923.0                 942.0
# 17                963.0                1001.0
# 18               1483.0                1559.0
# 19               1660.0                1660.0
# 20               1154.0                1173.0
# 21               1758.0                1796.0
# 22               1208.0                1227.0
# 23               1880.0                1880.0
# 24               2006.0                2006.0
# 25               1419.0                1419.0
# 26               1365.0                1498.0
# 27               2186.0                2566.0
# 28               1157.0                1252.0
# 29               2159.0                2273.0
# 30               1748.0                1767.0
# 31               1648.0                1743.0
# 32               1931.0                1950.0
# 33               2028.0                2104.0
# 34               2426.0                2502.0
# 35               2317.0                2431.0
# 36               1176.0                1309.0
# 37               1483.0                1521.0
# 38               2407.0                2445.0
# 39               1500.0                1576.0
# 40               2398.0                2607.0
# 41               3322.0                3360.0
# 42               3620.0                3715.0
# 43               9240.0                9278.0
# 44                227.0                 227.0

# %%
ws_avi_merged = ws_avi_19_22.merge(samon_byco, on=["Year", "Month"], how="left").drop("Date", axis=1)
ws_avi_merged.head(5)
# Out:
#    Year  Month  Number_of_flights_intl  Number_of_flights_total  \
# 0  2019      1                    90.0                     93.0
# 1  2019      2                    71.0                     84.0
# 2  2019      3                    85.0                    109.0
# 3  2019      4                    84.0                    117.0
# 4  2019      5                    85.0                    115.0
#
#    Seats_arrivals_intl  Seats_arrivals_total  Total arrivals (persons)  \
# 0              26332.0               26389.0                   13755.0
# 1              17320.0               17681.0                    9044.0
# 2              20843.0               21546.0                   11163.0
# 3              20801.0               21751.0                   14413.0
# 4              20843.0               21679.0                   13565.0
#
#       American Samoa     Australia     Europe     New Zealand     USA  \
# 0             1116.0        3434.0      612.0          6290.0   862.0
# 1              968.0        1820.0      458.0          3645.0   594.0
# 2             1089.0        2481.0      716.0          4400.0   981.0
# 3             1204.0        3122.0      658.0          6887.0   827.0
# 4             1215.0        3143.0      492.0          5742.0   962.0
#
#       Other Countries     Cruise ships
# 0              1441.0            500.0
# 1              1559.0           2180.0
# 2              1496.0           6730.0
# 3              1715.0           2519.0
# 4              2011.0              0.0

# %% [markdown]
# ## Correlation Analysis
# ### Ratio

# %%
ws_avi_merged["total_ratio"] = (ws_avi_merged["Total arrivals (persons)"] + 1) / \
    ws_avi_merged["Seats_arrivals_total"]

# %% [markdown]
# ### Pearson's

# %%
from scipy.stats import pearsonr


corr_seats, _ = pearsonr(
    ws_avi_merged["Seats_arrivals_total"], ws_avi_merged["Total arrivals (persons)"])
corr_seat_flight, _ = pearsonr(
    ws_avi_merged["Number_of_flights_total"],  ws_avi_merged["Total arrivals (persons)"])
print(
    f"Pearson Correlation between FlightRadar's Seats Arrival and WS's census data is{corr_seats: .4f}." 
    f"\nPearson Correlation between FlightRadar's # of Flights Arrival and WS's census data is{corr_seat_flight: .4f}.")
# Out:
# Pearson Correlation between FlightRadar's Seats Arrival and WS's census data is 0.9528.
# Pearson Correlation between FlightRadar's # of Flights Arrival and WS's census data is 0.9574.

# %% [markdown]
# ### ADF test

# %%
test_result = pd.DataFrame()
for col in ws_avi_merged.columns[2:]:
    col_result = adf_test(ws_avi_merged[col])
    col_result_df = pd.DataFrame(col_result)
    col_result_df.columns = [col]
    test_result = pd.concat([test_result, col_result_df.T], axis=0)
    
test_result
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.637057
# p-value                         0.463799
# # Lags Used                     0.000000
# Number of Observations Used    44.000000
# Critical Value (1%)            -3.588573
# Critical Value (5%)            -2.929886
# Critical Value (10%)           -2.603185
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.686990
# p-value                         0.437828
# # Lags Used                     5.000000
# Number of Observations Used    39.000000
# Critical Value (1%)            -3.610400
# Critical Value (5%)            -2.939109
# Critical Value (10%)           -2.608063
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.703234
# p-value                         0.429447
# # Lags Used                     7.000000
# Number of Observations Used    37.000000
# Critical Value (1%)            -3.620918
# Critical Value (5%)            -2.943539
# Critical Value (10%)           -2.610400
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.729472
# p-value                         0.415995
# # Lags Used                     7.000000
# Number of Observations Used    37.000000
# Critical Value (1%)            -3.620918
# Critical Value (5%)            -2.943539
# Critical Value (10%)           -2.610400
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.306947
# p-value                         0.169737
# # Lags Used                    10.000000
# Number of Observations Used    34.000000
# Critical Value (1%)            -3.639224
# Critical Value (5%)            -2.951230
# Critical Value (10%)           -2.614447
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.569532
# p-value                         0.498878
# # Lags Used                     0.000000
# Number of Observations Used    44.000000
# Critical Value (1%)            -3.588573
# Critical Value (5%)            -2.929886
# Critical Value (10%)           -2.603185
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.009189
# p-value                         0.282559
# # Lags Used                     0.000000
# Number of Observations Used    44.000000
# Critical Value (1%)            -3.588573
# Critical Value (5%)            -2.929886
# Critical Value (10%)           -2.603185
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -5.554803
# p-value                         0.000002
# # Lags Used                     7.000000
# Number of Observations Used    37.000000
# Critical Value (1%)            -3.620918
# Critical Value (5%)            -2.943539
# Critical Value (10%)           -2.610400
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.728973
# p-value                         0.416250
# # Lags Used                     0.000000
# Number of Observations Used    44.000000
# Critical Value (1%)            -3.588573
# Critical Value (5%)            -2.929886
# Critical Value (10%)           -2.603185
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.063186
# p-value                         0.029400
# # Lags Used                     7.000000
# Number of Observations Used    37.000000
# Critical Value (1%)            -3.620918
# Critical Value (5%)            -2.943539
# Critical Value (10%)           -2.610400
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.700482
# p-value                         0.073955
# # Lags Used                     9.000000
# Number of Observations Used    35.000000
# Critical Value (1%)            -3.632743
# Critical Value (5%)            -2.948510
# Critical Value (10%)           -2.613017
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.156132
# p-value                         0.000781
# # Lags Used                     1.000000
# Number of Observations Used    43.000000
# Critical Value (1%)            -3.592504
# Critical Value (5%)            -2.931550
# Critical Value (10%)           -2.604066
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                  0.347689
# p-value                         0.979430
# # Lags Used                     1.000000
# Number of Observations Used    43.000000
# Critical Value (1%)            -3.592504
# Critical Value (5%)            -2.931550
# Critical Value (10%)           -2.604066
# dtype: float64
#                           Test Statistic   p-value  # Lags Used  \
# Number_of_flights_intl         -1.637057  0.463799          0.0
# Number_of_flights_total        -1.686990  0.437828          5.0
# Seats_arrivals_intl            -1.703234  0.429447          7.0
# Seats_arrivals_total           -1.729472  0.415995          7.0
# Total arrivals (persons)       -2.306947  0.169737         10.0
#    American Samoa              -1.569532  0.498878          0.0
#    Australia                   -2.009189  0.282559          0.0
#    Europe                      -5.554803  0.000002          7.0
#    New Zealand                 -1.728973  0.416250          0.0
#    USA                         -3.063186  0.029400          7.0
#    Other Countries             -2.700482  0.073955          9.0
#    Cruise ships                -4.156132  0.000781          1.0
# total_ratio                     0.347689  0.979430          1.0
#
#                           Number of Observations Used  Critical Value (1%)  \
# Number_of_flights_intl                           44.0            -3.588573
# Number_of_flights_total                          39.0            -3.610400
# Seats_arrivals_intl                              37.0            -3.620918
# Seats_arrivals_total                             37.0            -3.620918
# Total arrivals (persons)                         34.0            -3.639224
#    American Samoa                                44.0            -3.588573
#    Australia                                     44.0            -3.588573
#    Europe                                        37.0            -3.620918
#    New Zealand                                   44.0            -3.588573
#    USA                                           37.0            -3.620918
#    Other Countries                               35.0            -3.632743
#    Cruise ships                                  43.0            -3.592504
# total_ratio                                      43.0            -3.592504
#
#                           Critical Value (5%)  Critical Value (10%)
# Number_of_flights_intl              -2.929886             -2.603185
# Number_of_flights_total             -2.939109             -2.608063
# Seats_arrivals_intl                 -2.943539             -2.610400
# Seats_arrivals_total                -2.943539             -2.610400
# Total arrivals (persons)            -2.951230             -2.614447
#    American Samoa                   -2.929886             -2.603185
#    Australia                        -2.929886             -2.603185
#    Europe                           -2.943539             -2.610400
#    New Zealand                      -2.929886             -2.603185
#    USA                              -2.943539             -2.610400
#    Other Countries                  -2.948510             -2.613017
#    Cruise ships                     -2.931550             -2.604066
# total_ratio                         -2.931550             -2.604066

# %% [markdown]
# ### Granger's Causality Test

# %%
grangers_causation_matrix(ws_avi_merged,
                          variables=["Total arrivals (persons)", "Seats_arrivals_total"],
                          maxlag=10)
# Out:
#                             Total arrivals (persons)_x  Seats_arrivals_total_x
# Total arrivals (persons)_y                         1.0                     0.0
# Seats_arrivals_total_y                             0.0                     1.0
