# %%
import os
os.chdir("../../")

import pandas as pd
import numpy as np
from statsmodels.tsa.vector_ar.vecm import VECM
from statsmodels.tsa.vector_ar.vecm import select_order
from scripts.python.tsa.mtsmodel import *
from scripts.python.tsa.ts_eval import *

import warnings
warnings.filterwarnings("ignore")

# %%
for country in ["palau", "samoa", "tonga", "solomon_islands", "vanuatu"]:
    mod = VARPipeline(country=country, data=None,
                      var_name=["total", "seats_arrivals_intl"],
                      exog=["covid", "stringency_index", "covid"])
    mod.read_and_merge()
    mod.test_stationarity()
    mod.transform()
    mod.varma_search()
    mod.fit()
    mod.get_fittedvalues()
    mod.evaluate_models()
# Out:
# order = 0: no stationarity obtained.
#                      Test Statistic   p-value  # Lags Used  \
# total                     -2.622492  0.088437          5.0
# seats_arrivals_intl       -5.476862  0.000002          0.0
#
#                      Number of Observations Used  Critical Value (1%)  \
# total                                       38.0            -3.615509
# seats_arrivals_intl                         43.0            -3.592504
#
#                      Critical Value (5%)  Critical Value (10%)
# total                          -2.941262             -2.609200
# seats_arrivals_intl            -2.931550             -2.604066
# order = 1: stationarity obtained.
#  Running for {'p': 1, 'q': 1, 'tr': 'n'}
#  Running for {'p': 1, 'q': 1, 'tr': 'c'}
#  Running for {'p': 1, 'q': 1, 'tr': 't'}
#  Running for {'p': 1, 'q': 1, 'tr': 'ct'}
#  Running for {'p': 1, 'q': 2, 'tr': 'n'}
#  Running for {'p': 1, 'q': 2, 'tr': 'c'}
#  Running for {'p': 1, 'q': 2, 'tr': 't'}
#  Running for {'p': 1, 'q': 2, 'tr': 'ct'}
#  Running for {'p': 1, 'q': 3, 'tr': 'n'}
#  Running for {'p': 1, 'q': 3, 'tr': 'c'}
#  Running for {'p': 1, 'q': 3, 'tr': 't'}
#  Running for {'p': 1, 'q': 3, 'tr': 'ct'}
#  Running for {'p': 2, 'q': 1, 'tr': 'n'}
#  Running for {'p': 2, 'q': 1, 'tr': 'c'}
#  Running for {'p': 2, 'q': 1, 'tr': 't'}
#  Running for {'p': 2, 'q': 1, 'tr': 'ct'}
#  Running for {'p': 2, 'q': 2, 'tr': 'n'}
#  Running for {'p': 2, 'q': 2, 'tr': 'c'}
#  Running for {'p': 2, 'q': 2, 'tr': 't'}
#  Running for {'p': 2, 'q': 2, 'tr': 'ct'}
#  Running for {'p': 2, 'q': 3, 'tr': 'n'}
#  Running for {'p': 2, 'q': 3, 'tr': 'c'}
#  Running for {'p': 2, 'q': 3, 'tr': 't'}
#  Running for {'p': 2, 'q': 3, 'tr': 'ct'}
#  Running for {'p': 3, 'q': 1, 'tr': 'n'}
#  Running for {'p': 3, 'q': 1, 'tr': 'c'}
#  Running for {'p': 3, 'q': 1, 'tr': 't'}
#  Running for {'p': 3, 'q': 1, 'tr': 'ct'}
#  Running for {'p': 3, 'q': 2, 'tr': 'n'}
#  Running for {'p': 3, 'q': 2, 'tr': 'c'}
#  Running for {'p': 3, 'q': 2, 'tr': 't'}
#  Running for {'p': 3, 'q': 2, 'tr': 'ct'}
#  Running for {'p': 3, 'q': 3, 'tr': 'n'}
#  Running for {'p': 3, 'q': 3, 'tr': 'c'}
#  Running for {'p': 3, 'q': 3, 'tr': 't'}
#  Running for {'p': 3, 'q': 3, 'tr': 'ct'}
# Best P, Q, Trend Combination: (3, 1, 't')
#                                   Statespace Model Results
# ============================================================================================
# Dep. Variable:     ['total', 'seats_arrivals_intl']   No. Observations:                   45
# Model:                                  VARMAX(3,1)   Log Likelihood                -124.461
#                                         + intercept   AIC                            302.923
# Date:                              Thu, 11 May 2023   BIC                            351.703
# Time:                                      17:49:54   HQIC                           321.108
# Sample:                                           0
#                                                - 45
# Covariance Type:                                opg
# ===================================================================================
# Ljung-Box (L1) (Q):             0.30, 0.06   Jarque-Bera (JB):        233.13, 35.28
# Prob(Q):                        0.58, 0.81   Prob(JB):                   0.00, 0.00
# Heteroskedasticity (H):         0.06, 0.12   Skew:                      2.77, -0.34
# Prob(H) (two-sided):            0.00, 0.00   Kurtosis:                  12.68, 7.28
#                                   Results for equation total
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# drift                         0.1532      0.152      1.008      0.313      -0.145       0.451
# L1.total                      0.6935      2.006      0.346      0.730      -3.238       4.625
# L1.seats_arrivals_intl        0.0215      2.741      0.008      0.994      -5.352       5.394
# L2.total                     -0.2521      2.208     -0.114      0.909      -4.580       4.076
# L2.seats_arrivals_intl       -0.2135      1.964     -0.109      0.913      -4.064       3.637
# L3.total                     -0.0565      1.070     -0.053      0.958      -2.154       2.041
# L3.seats_arrivals_intl       -0.1320      0.925     -0.143      0.887      -1.945       1.681
# L1.e(total)                   0.0196      2.055      0.010      0.992      -4.008       4.047
# L1.e(seats_arrivals_intl)    -0.8520      2.658     -0.321      0.749      -6.062       4.358
# beta.covid                   -4.5075      4.081     -1.105      0.269     -12.506       3.491
# beta.stringency_index         0.0191      0.059      0.322      0.747      -0.097       0.136
# beta.covid                   -4.5075      4.081     -1.105      0.269     -12.506       3.491
#                            Results for equation seats_arrivals_intl
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# drift                         0.2071      0.299      0.692      0.489      -0.380       0.794
# L1.total                      0.3064      0.731      0.419      0.675      -1.126       1.738
# L1.seats_arrivals_intl       -0.3916      1.027     -0.381      0.703      -2.405       1.622
# L2.total                      0.0982      1.310      0.075      0.940      -2.469       2.665
# L2.seats_arrivals_intl       -0.1935      1.288     -0.150      0.881      -2.717       2.330
# L3.total                     -0.2270      0.373     -0.609      0.543      -0.957       0.503
# L3.seats_arrivals_intl        0.0267      0.361      0.074      0.941      -0.681       0.735
# L1.e(total)                  -0.0826      0.683     -0.121      0.904      -1.421       1.256
# L1.e(seats_arrivals_intl)     0.1944      1.317      0.148      0.883      -2.386       2.775
# beta.covid                   -4.9146      8.130     -0.605      0.546     -20.849      11.020
# beta.stringency_index        -0.0049      0.057     -0.085      0.932      -0.117       0.107
# beta.covid                   -4.9146      8.130     -0.605      0.546     -20.849      11.020
#                                        Error covariance matrix
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# sqrt.var.total                         1.3587      0.529      2.568      0.010       0.322       2.396
# sqrt.cov.total.seats_arrivals_intl     1.1035      0.298      3.704      0.000       0.520       1.687
# sqrt.var.seats_arrivals_intl           0.6617      0.332      1.991      0.047       0.010       1.313
# ======================================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.24e+17. Standard errors may be unstable.
#                        MSE         RMSE          MAE       SMAPE
# naive         1.298621e+06  1139.570483   677.477273   53.868245
# mean          1.219030e+07  3491.460526  3125.890370  130.888109
# VAR (scaled)  1.127006e+06  1061.605449   554.935555   38.243616
# order = 0: no stationarity obtained.
# order = 1: no stationarity obtained.
#  Running for {'p': 1, 'q': 1, 'tr': 'n'}
#  Running for {'p': 1, 'q': 1, 'tr': 'c'}
#  Running for {'p': 1, 'q': 1, 'tr': 't'}
#  Running for {'p': 1, 'q': 1, 'tr': 'ct'}
#  Running for {'p': 1, 'q': 2, 'tr': 'n'}
#  Running for {'p': 1, 'q': 2, 'tr': 'c'}
#  Running for {'p': 1, 'q': 2, 'tr': 't'}
#  Running for {'p': 1, 'q': 2, 'tr': 'ct'}
#  Running for {'p': 1, 'q': 3, 'tr': 'n'}
#  Running for {'p': 1, 'q': 3, 'tr': 'c'}
#  Running for {'p': 1, 'q': 3, 'tr': 't'}
#  Running for {'p': 1, 'q': 3, 'tr': 'ct'}
#  Running for {'p': 2, 'q': 1, 'tr': 'n'}
#  Running for {'p': 2, 'q': 1, 'tr': 'c'}
#  Running for {'p': 2, 'q': 1, 'tr': 't'}
#  Running for {'p': 2, 'q': 1, 'tr': 'ct'}
#  Running for {'p': 2, 'q': 2, 'tr': 'n'}
#  Running for {'p': 2, 'q': 2, 'tr': 'c'}
#  Running for {'p': 2, 'q': 2, 'tr': 't'}
#  Running for {'p': 2, 'q': 2, 'tr': 'ct'}
#  Running for {'p': 2, 'q': 3, 'tr': 'n'}
#  Running for {'p': 2, 'q': 3, 'tr': 'c'}
#  Running for {'p': 2, 'q': 3, 'tr': 't'}
#  Running for {'p': 2, 'q': 3, 'tr': 'ct'}
#  Running for {'p': 3, 'q': 1, 'tr': 'n'}
#  Running for {'p': 3, 'q': 1, 'tr': 'c'}
#  Running for {'p': 3, 'q': 1, 'tr': 't'}
#  Running for {'p': 3, 'q': 1, 'tr': 'ct'}
#  Running for {'p': 3, 'q': 2, 'tr': 'n'}
#  Running for {'p': 3, 'q': 2, 'tr': 'c'}
#  Running for {'p': 3, 'q': 2, 'tr': 't'}
#  Running for {'p': 3, 'q': 2, 'tr': 'ct'}
#  Running for {'p': 3, 'q': 3, 'tr': 'n'}
#  Running for {'p': 3, 'q': 3, 'tr': 'c'}
#  Running for {'p': 3, 'q': 3, 'tr': 't'}
#  Running for {'p': 3, 'q': 3, 'tr': 'ct'}
# Best P, Q, Trend Combination: (1, 1, 'c')
#                                   Statespace Model Results
# ============================================================================================
# Dep. Variable:     ['total', 'seats_arrivals_intl']   No. Observations:                   45
# Model:                                  VARMAX(1,1)   Log Likelihood                -150.021
#                                         + intercept   AIC                            338.041
# Date:                              Thu, 11 May 2023   BIC                            372.368
# Time:                                      17:51:23   HQIC                           350.838
# Sample:                                           0
#                                                - 45
# Covariance Type:                                opg
# ===================================================================================
# Ljung-Box (L1) (Q):             0.26, 0.21   Jarque-Bera (JB):        303.19, 83.91
# Prob(Q):                        0.61, 0.65   Prob(JB):                   0.00, 0.00
# Heteroskedasticity (H):         0.60, 1.22   Skew:                      3.16, -0.89
# Prob(H) (two-sided):            0.33, 0.70   Kurtosis:                  14.03, 9.45
#                                   Results for equation total
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# intercept                     0.7106      2.797      0.254      0.799      -4.771       6.192
# L1.total                      0.4323      0.911      0.475      0.635      -1.353       2.218
# L1.seats_arrivals_intl        0.0696      0.881      0.079      0.937      -1.658       1.797
# L1.e(total)                   0.4995      0.887      0.563      0.573      -1.239       2.238
# L1.e(seats_arrivals_intl)    -0.9557      1.397     -0.684      0.494      -3.694       1.783
# beta.covid                   -0.8085      4.216     -0.192      0.848      -9.071       7.454
# beta.stringency_index        -0.0890      0.120     -0.741      0.459      -0.324       0.146
# beta.covid                   -0.8085      4.216     -0.192      0.848      -9.071       7.454
#                            Results for equation seats_arrivals_intl
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# intercept                     3.0195      1.317      2.293      0.022       0.439       5.600
# L1.total                     -0.1394      0.746     -0.187      0.852      -1.602       1.323
# L1.seats_arrivals_intl       -0.3394      0.709     -0.479      0.632      -1.729       1.050
# L1.e(total)                   0.2423      0.605      0.400      0.689      -0.944       1.429
# L1.e(seats_arrivals_intl)     0.2607      0.714      0.365      0.715      -1.138       1.659
# beta.covid                   -1.5307      2.774     -0.552      0.581      -6.968       3.906
# beta.stringency_index        -0.1142      0.079     -1.450      0.147      -0.268       0.040
# beta.covid                   -1.5307      2.774     -0.552      0.581      -6.968       3.906
#                                        Error covariance matrix
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# sqrt.var.total                         2.0024      0.816      2.453      0.014       0.403       3.602
# sqrt.cov.total.seats_arrivals_intl     1.2602      0.397      3.177      0.001       0.483       2.038
# sqrt.var.seats_arrivals_intl           0.8412      0.346      2.435      0.015       0.164       1.518
# ======================================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.04e+17. Standard errors may be unstable.
#                        MSE         RMSE          MAE       SMAPE
# naive         7.970104e+06  2823.137282  1518.795455   49.120902
# mean          4.747392e+07  6890.131975  6027.062716  155.537953
# VAR (scaled)  1.029089e+07  3207.941282  1757.557409  141.614714
# order = 0: no stationarity obtained.
#                      Test Statistic   p-value  # Lags Used  \
# total                     -2.948185  0.040025         10.0
# seats_arrivals_intl       -2.825820  0.054679          4.0
#
#                      Number of Observations Used  Critical Value (1%)  \
# total                                       26.0            -3.711212
# seats_arrivals_intl                         32.0            -3.653520
#
#                      Critical Value (5%)  Critical Value (10%)
# total                          -2.981247             -2.630095
# seats_arrivals_intl            -2.957219             -2.617588
# order = 1: stationarity obtained.
#  Running for {'p': 1, 'q': 1, 'tr': 'n'}
#  Running for {'p': 1, 'q': 1, 'tr': 'c'}
#  Running for {'p': 1, 'q': 1, 'tr': 't'}
#  Running for {'p': 1, 'q': 1, 'tr': 'ct'}
#  Running for {'p': 1, 'q': 2, 'tr': 'n'}
#  Running for {'p': 1, 'q': 2, 'tr': 'c'}
#  Running for {'p': 1, 'q': 2, 'tr': 't'}
#  Running for {'p': 1, 'q': 2, 'tr': 'ct'}
#  Running for {'p': 1, 'q': 3, 'tr': 'n'}
#  Running for {'p': 1, 'q': 3, 'tr': 'c'}
#  Running for {'p': 1, 'q': 3, 'tr': 't'}
#  Running for {'p': 1, 'q': 3, 'tr': 'ct'}
#  Running for {'p': 2, 'q': 1, 'tr': 'n'}
#  Running for {'p': 2, 'q': 1, 'tr': 'c'}
#  Running for {'p': 2, 'q': 1, 'tr': 't'}
#  Running for {'p': 2, 'q': 1, 'tr': 'ct'}
#  Running for {'p': 2, 'q': 2, 'tr': 'n'}
#  Running for {'p': 2, 'q': 2, 'tr': 'c'}
#  Running for {'p': 2, 'q': 2, 'tr': 't'}
#  Running for {'p': 2, 'q': 2, 'tr': 'ct'}
#  Running for {'p': 2, 'q': 3, 'tr': 'n'}
#  Running for {'p': 2, 'q': 3, 'tr': 'c'}
#  Running for {'p': 2, 'q': 3, 'tr': 't'}
#  Running for {'p': 2, 'q': 3, 'tr': 'ct'}
#  Running for {'p': 3, 'q': 1, 'tr': 'n'}
#  Running for {'p': 3, 'q': 1, 'tr': 'c'}
#  Running for {'p': 3, 'q': 1, 'tr': 't'}
#  Running for {'p': 3, 'q': 1, 'tr': 'ct'}
#  Running for {'p': 3, 'q': 2, 'tr': 'n'}
#  Running for {'p': 3, 'q': 2, 'tr': 'c'}
#  Running for {'p': 3, 'q': 2, 'tr': 't'}
#  Running for {'p': 3, 'q': 2, 'tr': 'ct'}
#  Running for {'p': 3, 'q': 3, 'tr': 'n'}
#  Running for {'p': 3, 'q': 3, 'tr': 'c'}
#  Running for {'p': 3, 'q': 3, 'tr': 't'}
#  Running for {'p': 3, 'q': 3, 'tr': 'ct'}
# Best P, Q, Trend Combination: (2, 1, 'c')
#                                   Statespace Model Results
# ============================================================================================
# Dep. Variable:     ['total', 'seats_arrivals_intl']   No. Observations:                   38
# Model:                                  VARMAX(2,1)   Log Likelihood                -140.022
#                                         + intercept   AIC                            326.044
# Date:                              Thu, 11 May 2023   BIC                            363.709
# Time:                                      17:52:43   HQIC                           339.445
# Sample:                                           0
#                                                - 38
# Covariance Type:                                opg
# ===================================================================================
# Ljung-Box (L1) (Q):             0.42, 2.05   Jarque-Bera (JB):       420.51, 103.96
# Prob(Q):                        0.52, 0.15   Prob(JB):                   0.00, 0.00
# Heteroskedasticity (H):         0.18, 0.09   Skew:                       3.25, 1.97
# Prob(H) (two-sided):            0.00, 0.00   Kurtosis:                 17.94, 10.08
#                                   Results for equation total
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# intercept                     1.3777      3.471      0.397      0.691      -5.425       8.181
# L1.total                     -0.0297      4.082     -0.007      0.994      -8.029       7.970
# L1.seats_arrivals_intl        0.3661      3.051      0.120      0.904      -5.613       6.346
# L2.total                     -0.0434      0.954     -0.045      0.964      -1.913       1.826
# L2.seats_arrivals_intl       -0.1236      0.847     -0.146      0.884      -1.784       1.536
# L1.e(total)                   0.1170      4.614      0.025      0.980      -8.927       9.161
# L1.e(seats_arrivals_intl)    -0.3579      3.060     -0.117      0.907      -6.355       5.640
# beta.covid                   -2.3416     10.479     -0.223      0.823     -22.880      18.197
# beta.stringency_index        -0.0717      0.275     -0.261      0.794      -0.610       0.467
# beta.covid                   -2.3416     10.479     -0.223      0.823     -22.880      18.197
#                            Results for equation seats_arrivals_intl
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# intercept                     1.2482      1.433      0.871      0.384      -1.560       4.057
# L1.total                      0.1544      1.350      0.114      0.909      -2.491       2.799
# L1.seats_arrivals_intl        0.8603      0.633      1.360      0.174      -0.380       2.100
# L2.total                     -0.3030      0.602     -0.503      0.615      -1.483       0.877
# L2.seats_arrivals_intl       -0.4030      0.264     -1.526      0.127      -0.921       0.115
# L1.e(total)                  -0.0023      1.497     -0.002      0.999      -2.937       2.933
# L1.e(seats_arrivals_intl)    -0.7844      0.798     -0.983      0.326      -2.349       0.780
# beta.covid                   -0.8908      3.482     -0.256      0.798      -7.716       5.934
# beta.stringency_index        -0.0452      0.088     -0.514      0.607      -0.218       0.127
# beta.covid                   -0.8908      3.482     -0.256      0.798      -7.716       5.934
#                                        Error covariance matrix
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# sqrt.var.total                         1.6869      0.305      5.528      0.000       1.089       2.285
# sqrt.cov.total.seats_arrivals_intl     0.2088      1.597      0.131      0.896      -2.921       3.338
# sqrt.var.seats_arrivals_intl           1.5215      0.293      5.187      0.000       0.947       2.096
# ======================================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.77e+17. Standard errors may be unstable.
#                        MSE         RMSE          MAE       SMAPE
# naive         1.776518e+06  1332.860792   647.945946   63.764255
# mean          1.368747e+07  3699.657587  3432.540166  154.297982
# VAR (scaled)  1.614325e+06  1270.560819   619.302843   58.747890
# order = 0: no stationarity obtained.
#                      Test Statistic   p-value  # Lags Used  \
# total                     -4.859232  0.000042          0.0
# seats_arrivals_intl       -2.697932  0.074397          9.0
#
#                      Number of Observations Used  Critical Value (1%)  \
# total                                       22.0            -3.769733
# seats_arrivals_intl                         13.0            -4.068854
#
#                      Critical Value (5%)  Critical Value (10%)
# total                          -3.005426             -2.642501
# seats_arrivals_intl            -3.127149             -2.701730
# order = 1: stationarity obtained.
#  Running for {'p': 1, 'q': 1, 'tr': 'n'}
#  Running for {'p': 1, 'q': 1, 'tr': 'c'}
#  Running for {'p': 1, 'q': 1, 'tr': 't'}
#  Running for {'p': 1, 'q': 1, 'tr': 'ct'}
#  Running for {'p': 1, 'q': 2, 'tr': 'n'}
#  Running for {'p': 1, 'q': 2, 'tr': 'c'}
#  Running for {'p': 1, 'q': 2, 'tr': 't'}
#  Running for {'p': 1, 'q': 2, 'tr': 'ct'}
#  Running for {'p': 1, 'q': 3, 'tr': 'n'}
#  Running for {'p': 1, 'q': 3, 'tr': 'c'}
#  Running for {'p': 1, 'q': 3, 'tr': 't'}
#  Running for {'p': 1, 'q': 3, 'tr': 'ct'}
#  Running for {'p': 2, 'q': 1, 'tr': 'n'}
#  Running for {'p': 2, 'q': 1, 'tr': 'c'}
#  Running for {'p': 2, 'q': 1, 'tr': 't'}
#  Running for {'p': 2, 'q': 1, 'tr': 'ct'}
#  Running for {'p': 2, 'q': 2, 'tr': 'n'}
#  Running for {'p': 2, 'q': 2, 'tr': 'c'}
#  Running for {'p': 2, 'q': 2, 'tr': 't'}
#  Running for {'p': 2, 'q': 2, 'tr': 'ct'}
#  Running for {'p': 2, 'q': 3, 'tr': 'n'}
#  Running for {'p': 2, 'q': 3, 'tr': 'c'}
#  Running for {'p': 2, 'q': 3, 'tr': 't'}
#  Running for {'p': 2, 'q': 3, 'tr': 'ct'}
#  Running for {'p': 3, 'q': 1, 'tr': 'n'}
#  Running for {'p': 3, 'q': 1, 'tr': 'c'}
#  Running for {'p': 3, 'q': 1, 'tr': 't'}
#  Running for {'p': 3, 'q': 1, 'tr': 'ct'}
#  Running for {'p': 3, 'q': 2, 'tr': 'n'}
#  Running for {'p': 3, 'q': 2, 'tr': 'c'}
#  Running for {'p': 3, 'q': 2, 'tr': 't'}
#  Running for {'p': 3, 'q': 2, 'tr': 'ct'}
#  Running for {'p': 3, 'q': 3, 'tr': 'n'}
#  Running for {'p': 3, 'q': 3, 'tr': 'c'}
#  Running for {'p': 3, 'q': 3, 'tr': 't'}
#  Running for {'p': 3, 'q': 3, 'tr': 'ct'}
# Best P, Q, Trend Combination: (1, 1, 'ct')
#                                   Statespace Model Results
# ============================================================================================
# Dep. Variable:     ['total', 'seats_arrivals_intl']   No. Observations:                   24
# Model:                                  VARMAX(1,1)   Log Likelihood                 -61.690
#                                         + intercept   AIC                            165.380
# Date:                              Thu, 11 May 2023   BIC                            190.119
# Time:                                      17:53:42   HQIC                           171.943
# Sample:                                           0
#                                                - 24
# Covariance Type:                                opg
# ===================================================================================
# Ljung-Box (L1) (Q):             1.75, 0.35   Jarque-Bera (JB):          0.37, 91.71
# Prob(Q):                        0.19, 0.55   Prob(JB):                   0.83, 0.00
# Heteroskedasticity (H):         0.83, 3.04   Skew:                       0.28, 2.41
# Prob(H) (two-sided):            0.80, 0.14   Kurtosis:                  2.75, 11.28
#                                   Results for equation total
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# intercept                     0.9646      7.078      0.136      0.892     -12.908      14.837
# intercept                     0.7162      8.942      0.080      0.936     -16.810      18.243
# L1.total                      0.0850      1.861      0.046      0.964      -3.563       3.733
# L1.seats_arrivals_intl       -0.1824      1.777     -0.103      0.918      -3.665       3.300
# L1.e(total)                   0.1519      2.814      0.054      0.957      -5.364       5.668
# L1.e(seats_arrivals_intl)     1.0805      2.247      0.481      0.631      -3.323       5.484
# beta.covid                   -1.4308      2.244     -0.638      0.524      -5.828       2.967
# beta.stringency_index        -0.1115      0.193     -0.579      0.562      -0.489       0.266
# beta.covid                   -1.4308      2.244     -0.638      0.524      -5.828       2.967
#                            Results for equation seats_arrivals_intl
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# drift                         0.1455      0.969      0.150      0.881      -1.754       2.045
# drift                         0.3453      0.964      0.358      0.720      -1.545       2.235
# L1.total                      0.4916      0.740      0.664      0.506      -0.959       1.942
# L1.seats_arrivals_intl       -0.6662      0.520     -1.281      0.200      -1.686       0.353
# L1.e(total)                  -0.3073      0.941     -0.327      0.744      -2.152       1.537
# L1.e(seats_arrivals_intl)     0.8599      1.688      0.509      0.611      -2.449       4.169
# beta.covid                   -1.3231      1.910     -0.693      0.488      -5.067       2.420
# beta.stringency_index        -0.1592      0.201     -0.791      0.429      -0.554       0.235
# beta.covid                   -1.3231      1.910     -0.693      0.488      -5.067       2.420
#                                        Error covariance matrix
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# sqrt.var.total                         0.5525      0.456      1.212      0.225      -0.341       1.446
# sqrt.cov.total.seats_arrivals_intl    -0.3034      3.635     -0.083      0.933      -7.427       6.820
# sqrt.var.seats_arrivals_intl           1.3951      0.885      1.576      0.115      -0.339       3.130
# ======================================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.55e+17. Standard errors may be unstable.
#                        MSE         RMSE          MAE       SMAPE
# naive         1.721267e+05   414.881597   268.478261   46.835106
# mean          1.290167e+06  1135.855000  1065.215278  100.969388
# VAR (scaled)  6.502167e+04   254.993470   154.338247   17.694166
# order = 0: no stationarity obtained.
#                      Test Statistic   p-value  # Lags Used  \
# total                     -4.688995  0.000088          0.0
# seats_arrivals_intl       -5.319799  0.000005          0.0
#
#                      Number of Observations Used  Critical Value (1%)  \
# total                                       41.0            -3.600983
# seats_arrivals_intl                         41.0            -3.600983
#
#                      Critical Value (5%)  Critical Value (10%)
# total                          -2.935135             -2.605963
# seats_arrivals_intl            -2.935135             -2.605963
# order = 1: stationarity obtained.
#  Running for {'p': 1, 'q': 1, 'tr': 'n'}
#  Running for {'p': 1, 'q': 1, 'tr': 'c'}
#  Running for {'p': 1, 'q': 1, 'tr': 't'}
#  Running for {'p': 1, 'q': 1, 'tr': 'ct'}
#  Running for {'p': 1, 'q': 2, 'tr': 'n'}
#  Running for {'p': 1, 'q': 2, 'tr': 'c'}
#  Running for {'p': 1, 'q': 2, 'tr': 't'}
#  Running for {'p': 1, 'q': 2, 'tr': 'ct'}
#  Running for {'p': 1, 'q': 3, 'tr': 'n'}
#  Running for {'p': 1, 'q': 3, 'tr': 'c'}
#  Running for {'p': 1, 'q': 3, 'tr': 't'}
#  Running for {'p': 1, 'q': 3, 'tr': 'ct'}
#  Running for {'p': 2, 'q': 1, 'tr': 'n'}
#  Running for {'p': 2, 'q': 1, 'tr': 'c'}
#  Running for {'p': 2, 'q': 1, 'tr': 't'}
#  Running for {'p': 2, 'q': 1, 'tr': 'ct'}
#  Running for {'p': 2, 'q': 2, 'tr': 'n'}
#  Running for {'p': 2, 'q': 2, 'tr': 'c'}
#  Running for {'p': 2, 'q': 2, 'tr': 't'}
#  Running for {'p': 2, 'q': 2, 'tr': 'ct'}
#  Running for {'p': 2, 'q': 3, 'tr': 'n'}
#  Running for {'p': 2, 'q': 3, 'tr': 'c'}
#  Running for {'p': 2, 'q': 3, 'tr': 't'}
#  Running for {'p': 2, 'q': 3, 'tr': 'ct'}
#  Running for {'p': 3, 'q': 1, 'tr': 'n'}
#  Running for {'p': 3, 'q': 1, 'tr': 'c'}
#  Running for {'p': 3, 'q': 1, 'tr': 't'}
#  Running for {'p': 3, 'q': 1, 'tr': 'ct'}
#  Running for {'p': 3, 'q': 2, 'tr': 'n'}
#  Running for {'p': 3, 'q': 2, 'tr': 'c'}
#  Running for {'p': 3, 'q': 2, 'tr': 't'}
#  Running for {'p': 3, 'q': 2, 'tr': 'ct'}
#  Running for {'p': 3, 'q': 3, 'tr': 'n'}
#  Running for {'p': 3, 'q': 3, 'tr': 'c'}
#  Running for {'p': 3, 'q': 3, 'tr': 't'}
#  Running for {'p': 3, 'q': 3, 'tr': 'ct'}
# Best P, Q, Trend Combination: (2, 2, 'c')
#                                   Statespace Model Results
# ============================================================================================
# Dep. Variable:     ['total', 'seats_arrivals_intl']   No. Observations:                   43
# Model:                                  VARMAX(2,2)   Log Likelihood                -156.966
#                                         + intercept   AIC                            367.932
# Date:                              Thu, 11 May 2023   BIC                            415.485
# Time:                                      17:55:08   HQIC                           385.468
# Sample:                                           0
#                                                - 43
# Covariance Type:                                opg
# ===================================================================================
# Ljung-Box (L1) (Q):             0.38, 1.22   Jarque-Bera (JB):         43.45, 85.76
# Prob(Q):                        0.54, 0.27   Prob(JB):                   0.00, 0.00
# Heteroskedasticity (H):         0.23, 0.85   Skew:                      1.25, -0.85
# Prob(H) (two-sided):            0.01, 0.76   Kurtosis:                   7.24, 9.71
#                                   Results for equation total
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# intercept                     2.7879      1.539      1.811      0.070      -0.229       5.805
# L1.total                      0.1296      0.453      0.286      0.775      -0.758       1.017
# L1.seats_arrivals_intl       -0.0458      0.782     -0.059      0.953      -1.579       1.487
# L2.total                     -0.0978      0.427     -0.229      0.819      -0.936       0.740
# L2.seats_arrivals_intl       -0.0299      0.594     -0.050      0.960      -1.194       1.134
# L1.e(total)                  -0.0571      0.491     -0.116      0.907      -1.020       0.906
# L1.e(seats_arrivals_intl)     0.0051      0.687      0.007      0.994      -1.341       1.351
# L2.e(total)                  -0.2549      0.350     -0.728      0.467      -0.941       0.431
# L2.e(seats_arrivals_intl)    -0.6611      0.605     -1.093      0.274      -1.847       0.524
# beta.covid                   -4.3852      1.703     -2.575      0.010      -7.723      -1.047
# beta.stringency_index        -0.0641      0.029     -2.242      0.025      -0.120      -0.008
# beta.covid                   -4.3852      1.703     -2.575      0.010      -7.723      -1.047
#                            Results for equation seats_arrivals_intl
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# intercept                     2.2902      2.130      1.075      0.282      -1.884       6.464
# L1.total                      0.4332      0.457      0.949      0.343      -0.462       1.328
# L1.seats_arrivals_intl        0.4219      0.582      0.725      0.469      -0.719       1.563
# L2.total                     -0.6276      0.383     -1.637      0.102      -1.379       0.124
# L2.seats_arrivals_intl       -0.0903      0.357     -0.253      0.800      -0.790       0.609
# L1.e(total)                  -0.3777      0.570     -0.663      0.507      -1.494       0.739
# L1.e(seats_arrivals_intl)     0.2111      0.628      0.336      0.737      -1.019       1.441
# L2.e(total)                   0.1953      0.699      0.279      0.780      -1.175       1.565
# L2.e(seats_arrivals_intl)    -0.1561      0.455     -0.343      0.732      -1.048       0.736
# beta.covid                   -2.1837      3.363     -0.649      0.516      -8.776       4.408
# beta.stringency_index        -0.0263      0.082     -0.321      0.748      -0.187       0.134
# beta.covid                   -2.1837      3.363     -0.649      0.516      -8.776       4.408
#                                        Error covariance matrix
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# sqrt.var.total                         1.1858      0.351      3.376      0.001       0.497       1.874
# sqrt.cov.total.seats_arrivals_intl     0.1719      0.856      0.201      0.841      -1.506       1.850
# sqrt.var.seats_arrivals_intl           1.5067      0.289      5.218      0.000       0.941       2.073
# ======================================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number  7e+18. Standard errors may be unstable.
#                        MSE         RMSE          MAE       SMAPE
# naive         2.446383e+06  1564.091833   808.452381   45.153360
# mean          2.273834e+07  4768.473803  4264.861006  156.566459
# VAR (scaled)  1.600258e+06  1265.013157   554.204122  134.493067

# %%
from statsmodels.tsa.api import VARMAX
mod = VARMAX(test.data[["total", "seats_arrivals_intl"]],
             exog=test.data[test.exog],
             order=(1, 3),
             trend="c").fit(disp=False)

print(calculate_evaluation(test.data["total"], naive_method(test.data["total"])))
print(calculate_evaluation(test.data["total"], mod.fittedvalues["total"]))
# Out:
# {'MSE': 1192288.1395348837, 'RMSE': 1091.9194748400103, 'MAE': 636.8837209302326, 'SMAPE': 54.46121058732388}
# {'MSE': 730352.211616988, 'RMSE': 854.6064659344604, 'MAE': 694.8881523051377, 'SMAPE': 86.16022388069882}

# %%
scaled = pd.DataFrame([test.x1_trans, test.x2_trans]).T
display(get_adf_df(scaled, ["total", "seats_arrivals_intl"]))

from sklearn.model_selection import ParameterGrid
param_grid = {'p': [1, 2, 3],
              'q': [1, 2, 3],
              'tr': ['n', 'c', 't', 'ct']}
pg = list(ParameterGrid(param_grid))

model_res = {
    "model": [],
    "result": []
}

for idx, params in enumerate(pg):
    print(f' Running for {params}')
    p = params.get('p')
    q = params.get('q')
    tr = params.get('tr')
    model = VARMAX(scaled,
                   exog=test.data[test.exog],
                   order=(p, q),
                   trend=tr).fit(disp=False)
    model_res["model"].append((p, q, tr))
    model_res["result"].append(model.aic)
# Out:
#                      Test Statistic   p-value  # Lags Used  \
# total                     -2.497021  0.116201          2.0
# seats_arrivals_intl       -2.837020  0.053177          2.0
#
#                      Number of Observations Used  Critical Value (1%)  \
# total                                       41.0            -3.600983
# seats_arrivals_intl                         41.0            -3.600983
#
#                      Critical Value (5%)  Critical Value (10%)
# total                          -2.935135             -2.605963
# seats_arrivals_intl            -2.935135             -2.605963
#  Running for {'p': 1, 'q': 1, 'tr': 'n'}
#  Running for {'p': 1, 'q': 1, 'tr': 'c'}
#  Running for {'p': 1, 'q': 1, 'tr': 't'}
#  Running for {'p': 1, 'q': 1, 'tr': 'ct'}
#  Running for {'p': 1, 'q': 2, 'tr': 'n'}
#  Running for {'p': 1, 'q': 2, 'tr': 'c'}
#  Running for {'p': 1, 'q': 2, 'tr': 't'}
#  Running for {'p': 1, 'q': 2, 'tr': 'ct'}
#  Running for {'p': 1, 'q': 3, 'tr': 'n'}
#  Running for {'p': 1, 'q': 3, 'tr': 'c'}
#  Running for {'p': 1, 'q': 3, 'tr': 't'}
#  Running for {'p': 1, 'q': 3, 'tr': 'ct'}
#  Running for {'p': 2, 'q': 1, 'tr': 'n'}
#  Running for {'p': 2, 'q': 1, 'tr': 'c'}
#  Running for {'p': 2, 'q': 1, 'tr': 't'}
#  Running for {'p': 2, 'q': 1, 'tr': 'ct'}
#  Running for {'p': 2, 'q': 2, 'tr': 'n'}
#  Running for {'p': 2, 'q': 2, 'tr': 'c'}
#  Running for {'p': 2, 'q': 2, 'tr': 't'}
#  Running for {'p': 2, 'q': 2, 'tr': 'ct'}
#  Running for {'p': 2, 'q': 3, 'tr': 'n'}
#  Running for {'p': 2, 'q': 3, 'tr': 'c'}
#  Running for {'p': 2, 'q': 3, 'tr': 't'}
#  Running for {'p': 2, 'q': 3, 'tr': 'ct'}
#  Running for {'p': 3, 'q': 1, 'tr': 'n'}
#  Running for {'p': 3, 'q': 1, 'tr': 'c'}
#  Running for {'p': 3, 'q': 1, 'tr': 't'}
#  Running for {'p': 3, 'q': 1, 'tr': 'ct'}
#  Running for {'p': 3, 'q': 2, 'tr': 'n'}
#  Running for {'p': 3, 'q': 2, 'tr': 'c'}
#  Running for {'p': 3, 'q': 2, 'tr': 't'}
#  Running for {'p': 3, 'q': 2, 'tr': 'ct'}
#  Running for {'p': 3, 'q': 3, 'tr': 'n'}
#  Running for {'p': 3, 'q': 3, 'tr': 'c'}
#  Running for {'p': 3, 'q': 3, 'tr': 't'}
#  Running for {'p': 3, 'q': 3, 'tr': 'ct'}

# %%
endog = test.data[["seats_arrivals_intl", "total"]]
exog = test.data[["covid", "stringency_index", "palau_travel"]]

# Determine the optimal lag order using the information criterion
lag_order = select_order(endog, maxlags=10, exog=exog)

# Create a VECM model with the selected lag order
model = VECM(endog, k_ar_diff=lag_order.selected_orders['aic'], exog=exog)

# Fit the VECM model
results = model.fit()

# Print the estimated parameters
print(results.summary())

# Get the long-run relationships (cointegrating vectors)
print(results.coint_rank)

# Perform Granger causality tests
granger_test = results.test_granger_causality(caused=1, causing=0)
print(granger_test.summary())
# Out:
# Det. terms outside the coint. relation & lagged endog. parameters for equation seats_arrivals_intl
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# exog1                       3.5720   1118.633      0.003      0.997   -2188.909    2196.053
# exog2                      -9.8641     17.907     -0.551      0.582     -44.961      25.233
# exog3                    2098.2777   1361.566      1.541      0.123    -570.342    4766.898
# L1.seats_arrivals_intl     -0.5823      0.220     -2.652      0.008      -1.013      -0.152
# L1.total                    0.9613      0.173      5.567      0.000       0.623       1.300
# L2.seats_arrivals_intl     -0.3897      0.318     -1.225      0.220      -1.013       0.234
# L2.total                    1.0455      0.436      2.398      0.016       0.191       1.900
# L3.seats_arrivals_intl     -0.1287      0.246     -0.524      0.600      -0.610       0.353
# L3.total                    1.3373      0.343      3.896      0.000       0.665       2.010
# L4.seats_arrivals_intl     -0.4568      0.251     -1.819      0.069      -0.949       0.035
# L4.total                   -0.3203      0.481     -0.666      0.506      -1.263       0.623
# L5.seats_arrivals_intl     -0.6224      0.270     -2.304      0.021      -1.152      -0.093
# L5.total                    1.1274      0.418      2.696      0.007       0.308       1.947
# L6.seats_arrivals_intl     -0.3563      0.256     -1.394      0.163      -0.857       0.145
# L6.total                    0.8935      0.589      1.517      0.129      -0.261       2.048
# L7.seats_arrivals_intl     -0.1726      0.349     -0.495      0.621      -0.856       0.511
# L7.total                    0.3546      0.431      0.823      0.410      -0.490       1.199
# L8.seats_arrivals_intl      0.0360      0.216      0.167      0.867      -0.387       0.459
# L8.total                    0.8963      0.556      1.611      0.107      -0.194       1.987
# L9.seats_arrivals_intl      0.1008      0.204      0.495      0.621      -0.299       0.500
# L9.total                    0.0791      0.425      0.186      0.852      -0.754       0.912
# L10.seats_arrivals_intl     0.0162      0.036      0.447      0.655      -0.055       0.087
# L10.total                  -0.4449      0.734     -0.607      0.544      -1.883       0.993
#     Det. terms outside the coint. relation & lagged endog. parameters for equation total
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# exog1                   -5349.9735    863.557     -6.195      0.000   -7042.514   -3657.433
# exog2                      81.6957     13.824      5.910      0.000      54.602     108.790
# exog3                    4645.3421   1051.095      4.420      0.000    2585.235    6705.450
# L1.seats_arrivals_intl      0.3023      0.169      1.784      0.074      -0.030       0.634
# L1.total                    0.8542      0.133      6.408      0.000       0.593       1.115
# L2.seats_arrivals_intl      1.5040      0.246      6.126      0.000       1.023       1.985
# L2.total                    1.3256      0.337      3.939      0.000       0.666       1.985
# L3.seats_arrivals_intl      0.4314      0.190      2.276      0.023       0.060       0.803
# L3.total                   -1.9889      0.265     -7.506      0.000      -2.508      -1.470
# L4.seats_arrivals_intl     -0.2504      0.194     -1.292      0.197      -0.630       0.130
# L4.total                   -1.6697      0.371     -4.495      0.000      -2.398      -0.942
# L5.seats_arrivals_intl     -0.1974      0.209     -0.946      0.344      -0.606       0.211
# L5.total                    0.2120      0.323      0.657      0.511      -0.421       0.845
# L6.seats_arrivals_intl      0.5692      0.197      2.885      0.004       0.182       0.956
# L6.total                    0.8808      0.455      1.937      0.053      -0.010       1.772
# L7.seats_arrivals_intl      1.3552      0.269      5.032      0.000       0.827       1.883
# L7.total                   -1.1606      0.332     -3.491      0.000      -1.812      -0.509
# L8.seats_arrivals_intl      0.9437      0.167      5.662      0.000       0.617       1.270
# L8.total                   -1.3203      0.429     -3.074      0.002      -2.162      -0.479
# L9.seats_arrivals_intl      0.7097      0.157      4.509      0.000       0.401       1.018
# L9.total                   -1.6147      0.328     -4.921      0.000      -2.258      -0.972
# L10.seats_arrivals_intl    -0.0301      0.028     -1.076      0.282      -0.085       0.025
# L10.total                  -2.7030      0.566     -4.773      0.000      -3.813      -1.593
#         Loading coefficients (alpha) for equation seats_arrivals_intl
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1            0.0098      0.062      0.159      0.874      -0.111       0.130
#                Loading coefficients (alpha) for equation total
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1            0.3643      0.047      7.671      0.000       0.271       0.457
#           Cointegration relations for loading-coefficients-column 1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# beta.1         1.0000          0          0      0.000       1.000       1.000
# beta.2        -5.0610      0.195    -26.006      0.000      -5.442      -4.680
# ==============================================================================
# 1
# Granger causality F-test. H_0: seats_arrivals_intl does not Granger-cause total. Conclusion: reject H_0 at 5% significance level.
# ==============================================
# Test statistic Critical value p-value    df
# ----------------------------------------------
#          53.90          2.943   0.000 (11, 10)
# ----------------------------------------------

# %%
calculate_evaluation(endog["total"], pd.DataFrame(results.fittedvalues)[1])
# Out:
# {'MSE': 19006337.115832955,
#  'RMSE': 4359.625799977901,
#  'MAE': 2870.2403678881547,
#  'SMAPE': 143.58928425671743}
